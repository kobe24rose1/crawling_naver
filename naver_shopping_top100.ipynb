# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000&listType=B10002')
soup = BeautifulSoup(res.content, 'html.parser')
data = soup.select('#productListArea > ul > li > p > a')
for index, item in enumerate(data):
    print(index+1, item.get_text())
# Out:
# 1 강블리 GBL 남여공용 무지 반팔 7색
# 2 안파 고급 실크 커플잠옷 ANPA03
# 3 나이키 드라이핏 스우시 반팔티 2컬러 3229...
# 4 라코스테 여성 릴랙스핏 원피스 EF2302-51G
# 5 아디다스 멀티쇼츠 에어로레디 멀티쇼츠 6종
# 6 아디다스 오리지널 티셔츠 드레스 TEE DRES...
# 7 알렌스틴 심리스 쿨 남성드로즈 기능성 남자...
# 8 폴로랄프로렌 크루넥 반팔 티셔츠 71061066...
# 9 아디다스 NEW 남성 35차 드로즈 9종 패키지
# 10 안파 체크 파자마 커플잠옷
# 11 메종키츠네 더블 폭스헤드 반팔 티셔츠 BU0...
# 12 캘빈클라인언더웨어 남자 팬티 속옷 드로즈...
# 13 안파 국민잠옷 바지 파자마 커플 홈웨어 체...
# 14 나이키 스우시 스포츠브라 BV3637-010
# 15 지오다노 여 버뮤다 쇼츠 400501
# 16 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 17 세트 드로즈 노메이커 에어리즘 남성 팬티 ...
# 18 달콤한레드 스윗드림 신혼부부 파자마 수면...
# 19 세일러 빅카라 여름 반팔 퍼프 베이비돌 셔...
# 20 카라V넥 루즈핏 반팔원피스 롱원피스 G1835...
# 21 안파 체크 커플 잠옷 파자마 디즈니 정품 푸...
# 22 라코스테 반팔 PK원피스 EF8470
# 23 이경희 아니버스 스킨 드로즈 남자팬티 -1도...
# 24 폴로랄프로렌 반팔 카라티셔츠 커스텀핏 커...
# 25 이경희 여성 여름 잠옷
# 26 써스데이아일랜드 핀턱디테일 롱 원피스 T2...
# 27 V넥단추A라인면원피스 VW5OPV3
# 28 안파 체크 커플 잠옷 파자마 디즈니 정품 솜...
# 29 하이서포트 브라탑 스포츠 브라
# 30 캘빈클라인언더웨어 언더웨어 ICON 푸쉬업 ...
# 31 캘빈클라인언더웨어 모던코튼 스트레치 2PK...
# 32 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 33 여성 여자 2021 여름 반팔 잠옷 원피스 캐릭...
# 34 나이키 드라이 핏 레전드 2.0 718834
# 35 아디다스 클라이마라이트 트렁크 7종 패키지
# 36 라코스테 여성 A라 인릴랙스핏 헤리티지 폴...
# 37 메종키츠네 21 S S 여성 헤드폭스 패치 반팔...
# 38 모달 심리스 남자팬티 드로즈 4장세트
# 39 안파 커플잠옷 면 고급 파자마 ANPA08
# 40 이경희 수면 파자마 홈웨어 라운지
# 41 캘빈클라인언더웨어 CK 언더웨어 모던코튼 ...
# 42 지오다노 헤비코튼 크루넥 반팔 티셔츠 021...
# 43 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 44 여자파자마 세트 여름 잠옷 냉장고 잠옷 지...
# 45 트라이 내맘대로 나노실버 코튼 남성 트렁크...
# 46 써스데이아일랜드 스모킹 변형 절개 소매 원...
# 47 반팔파자마 여름 면 잠옷 파자마세트 투피스
# 48 아디다스 파르마16 쇼트 속팬츠 반바지 AJ5...
# 49 안파 커플 잠옷 파자마 디즈니 정품 미키 A...
# 50 지오다노 여 밴딩 이지쇼츠 401504
# 51 강블리 블링 브라&팬티 세트
# 52 비비안 노와이어 인견메쉬브라 NC경산점 BR...
# 53 나이키 스포츠웨어 우븐 쇼츠 멘즈 검흰 데...
# 54 리무브 클래식 니플커버 니플패치 누드브라
# 55 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 56 무봉제팬티 심리스 여성 노라인 팬티 속옷 ...
# 57 폴햄 21년 여름신상 남자 테이퍼드핏 밴딩슬...
# 58 아디다스 MH 1 4 반바지 여자 머스트해브 트...
# 59 나이키 NSW 클럽 반팔티 AR4997
# 60 코데즈컴바인이너웨어 21 썸머쿨 RD 남성드...
# 61 라코스테 벨티드 피케 원피스 EF5471
# 62 캘빈클라인언더웨어 여성 모던 코튼 트라이...
# 63 푸마 여성 얼티밋핏 RE 브라팬티 컬렉션 10...
# 64 라코스테 크루넥 반팔 레귤러핏 티셔츠 TF7...
# 65 나이키 스포츠브라 CN3719-010
# 66 트라이 쾌적한 순면 트렁크 남성팬티 5종세...
# 67 라인 N703 소매 핀턱 보트넥 블라우스 NGBL...
# 68 언더아머 Tech 반팔 1326413-001
# 69 지오다노 여 린넨 와이드 풀밴딩 팬츠 4115...
# 70 1+1 면 브라렛 노와이어 브라탑 심리스 빅사...
# 71 플라스틱아일랜드 컬러배색 스모킹 티어드 ...
# 72 아디다스 퍼포먼스 남성 반바지 M 첼시아 G...
# 73 아디다스 클라이마쿨 56차 드로즈 1종 남성
# 74 21년 썸머 유니스킨 인견 에어 심리스 브라...
# 75 조거 팬츠 남자 트레이닝복 조커 여름 냉장...
# 76 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 77 크로커다일 감탄브라 노와이어 인견쿨 슬림...
# 78 캘빈클라인언더웨어 언더웨어 모던코튼 트라...
# 79 나이키 플렉스 우븐 쇼츠 CU4946-010
# 80 에블린 속옷세트 스프링 울트라푸쉬 브라 헴...
# 81 나이키 스포츠웨어 우븐 쇼츠 AR2383-800
# 82 신상특가 모그핑크 클라우디 심리스 사각팬...
# 83 언더아머 남성 드로즈 차지드코튼 3in 3 13...
# 84 아디다스 에어로레디 드로즈 9종 패키지 62...
# 85 헤지스 남성 퍼피자수 면 반팔티셔츠 WHTS0...
# 86 라코스테 여성 릴렉스핏 원피스 EF401E-51G
# 87 리스트 20여름 민소매 포켓 롱원피스 TWWOP...
# 88 지오다노 지오다노 남 쿨 슬랙스 테이퍼드핏...
# 89 나이키 N 하이 서포트 스포츠브라 AJ0844-0...
# 90 폴햄 여름신상 남성 테이퍼드핏 올밴딩 슬랙...
# 91 지오다노 폴로넥 티셔츠 011502
# 92 쉬즈미스 루즈핏 티어드 롱 원피스 SWWOPL2...
# 93 푸마 여성 에어리 서포트 브라팬티 7세트
# 94 비너스자스민 심리스 무봉제 노와이어 누디...
# 95 라코스테 반팔카라티 초경량 테니스 셔츠 L...
# 96 홀리지 리머 노와이어 데일리 브라탑 브라렛
# 97 지오다노 린넨쇼츠 401507
# 98 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 99 나이키 W NSW 우븐 쇼츠 CJ1689-010
# 100 게스 여성 오리지날 반팔티 YL2K9405
